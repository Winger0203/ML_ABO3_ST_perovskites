# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Train-test.csv")

# %%
print(df)
# Out:
#     A AtomicMass  A NumberofNeutrons  A NumberofProtons  A NumberofElectrons  \
# 0        207.200                 125                 82                   82
# 1        208.980                 126                 83                   83
# 2        207.200                 125                 82                   82
# 3         87.620                  50                 38                   38
# 4        138.905                  82                 57                   57
# 5        137.327                  81                 56                   56
# 6         40.078                  20                 20                   20
# 7         40.078                  20                 20                   20
# 8        137.327                  81                 56                   56
# 9         24.305                  12                 12                   12
# 10        40.078                  20                 20                   20
# 11        87.620                  50                 38                   38
# 12        87.620                  50                 38                   38
# 13        87.620                  50                 38                   38
# 14         9.012                   5                  4                    4
# 15         9.012                   5                  4                    4
# 16         9.012                   5                  4                    4
# 17        40.078                  20                 20                   20
# 18        87.620                  50                 38                   38
# 19       137.327                  81                 56                   56
# 20       137.327                  81                 56                   56
# 21       158.925                  94                 65                   65
# 22       138.905                  82                 57                   57
# 23        63.546                  35                 29                   29
# 24        65.380                  35                 30                   30
# 25       112.411                  64                 48                   48
# 26       173.054                 103                 70                   70
# 27       173.054                 103                 70                   70
# 28        50.942                  28                 23                   23
# 29        47.867                  26                 22                   22
# ..           ...                 ...                ...                  ...
# 65       132.905                  78                 55                   55
# 66       132.905                  78                 55                   55
# 67       132.905                  78                 55                   55
# 68       132.905                  78                 55                   55
# 69       132.905                  78                 55                   55
# 70       132.905                  78                 55                   55
# 71       132.905                  78                 55                   55
# 72       132.905                  78                 55                   55
# 73       132.905                  78                 55                   55
# 74       132.905                  78                 55                   55
# 75       132.905                  78                 55                   55
# 76       132.905                  78                 55                   55
# 77       132.905                  78                 55                   55
# 78         6.941                   4                  3                    3
# 79         6.941                   4                  3                    3
# 80         6.941                   4                  3                    3
# 81         6.941                   4                  3                    3
# 82         6.941                   4                  3                    3
# 83        22.990                  12                 11                   11
# 84        22.990                  12                 11                   11
# 85        22.990                  12                 11                   11
# 86        39.098                  20                 19                   19
# 87        39.098                  20                 19                   19
# 88        39.098                  20                 19                   19
# 89        39.098                  20                 19                   19
# 90        39.098                  20                 19                   19
# 91        39.098                  20                 19                   19
# 92        39.098                  20                 19                   19
# 93        39.098                  20                 19                   19
# 94        39.098                  20                 19                   19
#
#     A Period  A Electronegativity  A FirstIonization  A Density  \
# 0          6                 2.33             7.4167     11.300
# 1          6                 2.02             7.2856      9.810
# 2          6                 2.33             7.4167     11.300
# 3          5                 0.95             5.6949      2.640
# 4          6                 1.10             5.5769      6.150
# 5          6                 0.89             5.2117      3.590
# 6          4                 1.00             6.1132      1.540
# 7          4                 1.00             6.1132      1.540
# 8          6                 0.89             5.2117      3.590
# 9          3                 1.31             7.6462      1.740
# 10         4                 1.00             6.1132      1.540
# 11         5                 0.95             5.6949      2.640
# 12         5                 0.95             5.6949      2.640
# 13         5                 0.95             5.6949      2.640
# 14         2                 1.57             9.3227      1.850
# 15         2                 1.57             9.3227      1.850
# 16         2                 1.57             9.3227      1.850
# 17         4                 1.00             6.1132      1.540
# 18         5                 0.95             5.6949      2.640
# 19         6                 0.89             5.2117      3.590
# 20         6                 0.89             5.2117      3.590
# 21         6                 1.20             5.8638      8.230
# 22         6                 1.10             5.5769      6.150
# 23         4                 1.90             7.7264      8.960
# 24         4                 1.65             9.3942      7.130
# 25         5                 1.69             8.9938      8.690
# 26         6                 1.10             6.2542      6.970
# 27         6                 1.10             6.2542      6.970
# 28         4                 1.63             6.7462      6.110
# 29         4                 1.54             6.8281      4.540
# ..       ...                  ...                ...        ...
# 65         6                 0.79             3.8939      1.870
# 66         6                 0.79             3.8939      1.870
# 67         6                 0.79             3.8939      1.870
# 68         6                 0.79             3.8939      1.870
# 69         6                 0.79             3.8939      1.870
# 70         6                 0.79             3.8939      1.870
# 71         6                 0.79             3.8939      1.870
# 72         6                 0.79             3.8939      1.870
# 73         6                 0.79             3.8939      1.870
# 74         6                 0.79             3.8939      1.870
# 75         6                 0.79             3.8939      1.870
# 76         6                 0.79             3.8939      1.870
# 77         6                 0.79             3.8939      1.870
# 78         2                 0.98             5.3917      0.534
# 79         2                 0.98             5.3917      0.534
# 80         2                 0.98             5.3917      0.534
# 81         2                 0.98             5.3917      0.534
# 82         2                 0.98             5.3917      0.534
# 83         3                 0.93             5.1391      0.971
# 84         3                 0.93             5.1391      0.971
# 85         3                 0.93             5.1391      0.971
# 86         4                 0.82             4.3407      0.862
# 87         4                 0.82             4.3407      0.862
# 88         4                 0.82             4.3407      0.862
# 89         4                 0.82             4.3407      0.862
# 90         4                 0.82             4.3407      0.862
# 91         4                 0.82             4.3407      0.862
# 92         4                 0.82             4.3407      0.862
# 93         4                 0.82             4.3407      0.862
# 94         4                 0.82             4.3407      0.862
#
#     A MeltingPoint  A BoilingPoint    ...     X MeltingPoint  X BoilingPoint  \
# 0           600.75            2022    ...              50.50           90.20
# 1           544.67            1837    ...              50.50           90.20
# 2           600.75            2022    ...              50.50           90.20
# 3          1042.15            1655    ...              50.50           90.20
# 4          1193.15            3737    ...              50.50           90.20
# 5          1002.15            2170    ...              50.50           90.20
# 6          1112.15            1757    ...              50.50           90.20
# 7          1112.15            1757    ...              50.50           90.20
# 8          1002.15            2170    ...              50.50           90.20
# 9           923.15            1363    ...              50.50           90.20
# 10         1112.15            1757    ...              50.50           90.20
# 11         1042.15            1655    ...              50.50           90.20
# 12         1042.15            1655    ...              50.50           90.20
# 13         1042.15            1655    ...              50.50           90.20
# 14         1560.15            2742    ...              50.50           90.20
# 15         1560.15            2742    ...              50.50           90.20
# 16         1560.15            2742    ...              50.50           90.20
# 17         1112.15            1757    ...              50.50           90.20
# 18         1042.15            1655    ...              50.50           90.20
# 19         1002.15            2170    ...              50.50           90.20
# 20         1002.15            2170    ...              50.50           90.20
# 21         1630.15            3503    ...              50.50           90.20
# 22         1193.15            3737    ...              50.50           90.20
# 23         1357.75            2835    ...              50.50           90.20
# 24          692.88            1180    ...              50.50           90.20
# 25          594.33            1040    ...              50.50           90.20
# 26         1097.15            1469    ...              50.50           90.20
# 27         1097.15            1469    ...              50.50           90.20
# 28         2175.15            3680    ...              50.50           90.20
# 29         1933.15            3560    ...              50.50           90.20
# ..             ...             ...    ...                ...             ...
# 65          301.70             944    ...              53.63           85.03
# 66          301.70             944    ...              53.63           85.03
# 67          301.70             944    ...              53.63           85.03
# 68          301.70             944    ...             172.31          239.11
# 69          301.70             944    ...             172.31          239.11
# 70          301.70             944    ...             172.31          239.11
# 71          301.70             944    ...             172.31          239.11
# 72          301.70             944    ...             266.05          332.00
# 73          301.70             944    ...             266.05          332.00
# 74          301.70             944    ...             266.05          332.00
# 75          301.70             944    ...             266.05          332.00
# 76          301.70             944    ...             266.05          332.00
# 77          301.70             944    ...             266.05          332.00
# 78          453.85            1615    ...              53.63           85.03
# 79          453.85            1615    ...              53.63           85.03
# 80          453.85            1615    ...              53.63           85.03
# 81          453.85            1615    ...              53.63           85.03
# 82          453.85            1615    ...             172.31          239.11
# 83          371.15            1156    ...              53.63           85.03
# 84          371.15            1156    ...              53.63           85.03
# 85          371.15            1156    ...              53.63           85.03
# 86          336.50            1032    ...              53.63           85.03
# 87          336.50            1032    ...              53.63           85.03
# 88          336.50            1032    ...             172.31          239.11
# 89          336.50            1032    ...             172.31          239.11
# 90          336.50            1032    ...             172.31          239.11
# 91          336.50            1032    ...             266.05          332.00
# 92          336.50            1032    ...             386.65          457.40
# 93          336.50            1032    ...             266.05          332.00
# 94          336.50            1032    ...             266.05          332.00
#
#     X SpecificHeat  X NumberofShells  A Ionic radius (pm)  B Ionic radius  \
# 0            0.918                 2                119.0            60.5
# 1            0.918                 2                103.0            58.5
# 2            0.918                 2                119.0            58.0
# 3            0.918                 2                112.0            60.5
# 4            0.918                 2                 57.0            53.5
# 5            0.918                 2                135.0            77.5
# 6            0.918                 2                 99.0            60.5
# 7            0.918                 2                 99.0            40.0
# 8            0.918                 2                135.0            60.5
# 9            0.918                 2                 72.0            40.0
# 10           0.918                 2                 99.0            53.0
# 11           0.918                 2                112.0            53.0
# 12           0.918                 2                112.0            71.0
# 13           0.918                 2                112.0            69.0
# 14           0.918                 2                 45.0            58.0
# 15           0.918                 2                 45.0           102.0
# 16           0.918                 2                 45.0            60.0
# 17           0.918                 2                 99.0            58.0
# 18           0.918                 2                112.0            90.1
# 19           0.918                 2                135.0            53.0
# 20           0.918                 2                135.0            94.0
# 21           0.918                 2                 76.0            69.0
# 22           0.918                 2                 57.0            69.0
# 23           0.918                 2                 73.0           102.0
# 24           0.918                 2                 74.0            40.0
# 25           0.918                 2                 97.0            53.0
# 26           0.918                 2                102.0            86.0
# 27           0.918                 2                102.0            60.5
# 28           0.918                 2                 64.0           102.0
# 29           0.918                 2                 86.0            73.0
# ..             ...               ...                  ...             ...
# 65           0.824                 2                167.0            45.0
# 66           0.824                 2                167.0            72.0
# 67           0.824                 2                167.0            86.0
# 68           0.479                 3                167.0            94.0
# 79             133             0.738927              0.503759  1.008958
# 80             133             0.750179              0.481203  1.000000
# 81             133             0.637006              0.744361  1.000000
# 82             181             0.680623              0.475138  0.960474
# 83             133             0.810586              0.541353  1.000000
# 84             133             0.843503              0.481203  1.000000
# 85             133             0.758768              0.646617  1.000000
# 86             133             0.930223              0.548872  1.458763
# 87             133             0.948643              0.518797  1.000000
# 88             181             0.888059              0.403315  1.000000
# 89             181             0.805597              0.546961  1.000000
# 90             181             0.820244              0.519337  1.001976
# 91             196             0.855702              0.408163  1.000000
# 92             220             0.843814              0.363636  1.000000
# 93             196             0.830136              0.451531  1.000000
# 94             196             0.814392              0.479592  0.705416
#
# [95 rows x 42 columns]

# %%
print(df.columns)
# Out:
# Index(['A AtomicMass', 'A NumberofNeutrons', 'A NumberofProtons',
#        'A NumberofElectrons', 'A Period', 'A Electronegativity',
#        'A FirstIonization', 'A Density', 'A MeltingPoint', 'A BoilingPoint',
#        'A SpecificHeat', 'A NumberofShells', 'B AtomicMass',
#        'B NumberofNeutrons', 'B NumberofProtons', 'B NumberofElectrons',
#        'B Period', 'B Electronegativity', 'B FirstIonization', 'B Density',
#        'B MeltingPoint', 'B BoilingPoint', 'B SpecificHeat',
#        'B NumberofShells', 'X AtomicMass', 'X NumberofNeutrons',
#        'X NumberofProtons', 'X NumberofElectrons', 'X Period',
#        'X Electronegativity', 'X FirstIonization', 'X Density',
#        'X MeltingPoint', 'X BoilingPoint', 'X SpecificHeat',
#        'X NumberofShells', 'A Ionic radius (pm)', 'B Ionic radius',
#        'X Ionic radius', 'Tolerance factor(t)', 'octahedral factor(u)', 'c/a'],
#       dtype='object')

# %%
import matplotlib.pyplot as plot
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas import DataFrame

# %%
dataset= r'Train-test.csv'
data=pd.DataFrame(pd.read_csv(dataset))
featureData=data.iloc[:,:]
corMat = DataFrame(featureData.corr())  #corr 求相关系数矩阵
print(corMat)
writer = pd.ExcelWriter('2.xlsx')
corMat.to_excel(writer,'Sheet1')
writer.save()
plt.figure(figsize=(20, 30))
sns.heatmap(corMat, annot=False, vmax=1, square=True, cmap="Blues",linewidths=0)
plot.show()
# Out:
#                       A AtomicMass  A NumberofNeutrons  A NumberofProtons  \
# A AtomicMass              1.000000            0.999355           0.998517
# A NumberofNeutrons        0.999355            1.000000           0.995960
# A NumberofProtons         0.998517            0.995960           1.000000
# A NumberofElectrons       0.998517            0.995960           1.000000
# A Period                  0.910014            0.897734           0.926568
# A Electronegativity       0.240865            0.248034           0.230583
# A FirstIonization        -0.056307           -0.048191          -0.067267
# A Density                 0.620783            0.621584           0.618750
# A MeltingPoint            0.036419            0.033900           0.042771
# A BoilingPoint            0.100003            0.100494           0.101360
# A SpecificHeat           -0.665204           -0.642248          -0.698257
# A NumberofShells          0.910014            0.897734           0.926568
# B AtomicMass              0.200485            0.196479           0.205784
# B NumberofNeutrons        0.036483            0.031240           0.044848
# B NumberofProtons         0.199375            0.195110           0.205090
# X FirstIonization               -0.169329 -0.206861            -0.115398
# X Density                       -0.004041  0.111568            -0.319488
# X MeltingPoint                  -0.028836  0.113521            -0.424062
# X BoilingPoint                  -0.021704  0.119832            -0.414285
# X SpecificHeat                   0.082216 -0.073153             0.525915
# X NumberofShells                -0.021990  0.118446            -0.412530
# A Ionic radius (pm)              0.296448  0.513672            -0.659193
# B Ionic radius                   0.078944  0.173833            -0.309011
# X Ionic radius                  -0.001676  0.134956            -0.378610
# Tolerance factor(t)              0.242807  0.370498            -0.360813
# octahedral factor(u)             0.071632  0.100396            -0.132964
# c/a                              0.044830  0.074441            -0.118709
#
#                       A FirstIonization  A Density  A MeltingPoint  \
# A AtomicMass                  -0.056307   0.620783        0.036419
# A NumberofNeutrons            -0.048191   0.621584        0.033900
# A NumberofProtons             -0.067267   0.618750        0.042771
# A NumberofElectrons           -0.067267   0.618750        0.042771
# A Period                      -0.314820   0.393948       -0.036016
# A Electronegativity            0.837437   0.769792        0.498931
# A FirstIonization              1.000000   0.583899        0.636643
# A Density                      0.583899   1.000000        0.595328
# A MeltingPoint                 0.636643   0.595328        1.000000
# A BoilingPoint                 0.589535   0.649901        0.949115
# A SpecificHeat                 0.106935  -0.373927       -0.110533
# A NumberofShells              -0.314820   0.393948       -0.036016
# B AtomicMass                  -0.080845   0.071725        0.070368
# B NumberofNeutrons            -0.088400   0.003664        0.022564
# B NumberofProtons             -0.086813   0.070193        0.070513
# B NumberofElectrons           -0.086813   0.070193        0.070513
# B Period                      -0.120484   0.029947        0.049121
# B Electronegativity            0.168303   0.223405        0.111397
# B FirstIonization              0.304306   0.204483        0.166697
# B Density                     -0.020638   0.102204        0.046495
# B MeltingPoint                 0.094940  -0.038020       -0.078764
# B BoilingPoint                 0.127374   0.082407       -0.006145
# B SpecificHeat                 0.007280  -0.092224       -0.110029
# B NumberofShells              -0.120484   0.029947        0.049121
# X AtomicMass                  -0.477082  -0.333244       -0.398654
# X NumberofNeutrons            -0.470367  -0.329102       -0.393491
# X NumberofProtons             -0.482308  -0.335844       -0.402253
# X NumberofElectrons           -0.482308  -0.335844       -0.402253
# X Period                      -0.501260  -0.346440       -0.415837
# X Electronegativity            0.074096  -0.019563        0.010145
# X FirstIonization             -0.099220  -0.159827       -0.148126
# X Density                     -0.391014  -0.262854       -0.320538
# X MeltingPoint                -0.514013  -0.358222       -0.428284
# X BoilingPoint                -0.503712  -0.347696       -0.417173
# X SpecificHeat                 0.626417   0.462059        0.539170
# X NumberofShells              -0.501260  -0.346440       -0.415837
# A Ionic radius (pm)           -0.839205  -0.447868       -0.705508
# B Ionic radius                -0.389479  -0.156456       -0.075974
# X Ionic radius                -0.464741  -0.311244       -0.377747
# Tolerance factor(t)           -0.476797  -0.263312       -0.577025
# octahedral factor(u)          -0.172303   0.000669        0.140091
# c/a                           -0.104329  -0.101630       -0.139961
#
#                       A BoilingPoint    ...     X MeltingPoint  \
# A AtomicMass                0.100003    ...          -0.038343
# A NumberofNeutrons          0.100494    ...          -0.046174
# A NumberofProtons           0.101360    ...          -0.028836
# A NumberofElectrons         0.101360    ...          -0.028836
# A Period                   -0.007196    ...           0.113521
# A Electronegativity         0.548883    ...          -0.424062
# A FirstIonization           0.589535    ...          -0.514013
# A Density                   0.649901    ...          -0.358222
# A MeltingPoint              0.949115    ...          -0.428284
# A BoilingPoint              1.000000    ...          -0.419045
# A SpecificHeat             -0.067200    ...          -0.080207
# A NumberofShells           -0.007196    ...           0.113521
# B AtomicMass                0.046336    ...           0.228293
# B NumberofNeutrons          0.040765    ...           0.268355
# B NumberofProtons           0.047706    ...           0.236729
# B NumberofElectrons         0.047706    ...           0.236729
# B Period                    0.021503    ...           0.245616
# B Electronegativity         0.130956    ...           0.034447
# B FirstIonization           0.175793    ...          -0.238103
# B Density                   0.071667    ...           0.105427
# B MeltingPoint             -0.069818    ...          -0.299920
# B BoilingPoint             -0.027168    ...          -0.221944
# B SpecificHeat             -0.088660    ...          -0.238255
# B NumberofShells            0.021503    ...           0.245616
# X AtomicMass               -0.390648    ...           0.976379
# X NumberofNeutrons         -0.385580    ...           0.968966
# X NumberofProtons          -0.394309    ...           0.982727
# X NumberofElectrons        -0.394309    ...           0.982727
# X Period                   -0.407783    ...           0.998869
# X Electronegativity         0.033533    ...          -0.788103
# X FirstIonization          -0.114645    ...          -0.641461
# X Density                  -0.317791    ...           0.911860
# X MeltingPoint             -0.419045    ...           1.000000
# X BoilingPoint             -0.409100    ...           0.998397
# X SpecificHeat              0.518532    ...          -0.951534
# X NumberofShells           -0.407783    ...           0.998869
# A Ionic radius (pm)        -0.728639    ...           0.533159
# B Ionic radius             -0.066892    ...           0.388796
# X Ionic radius             -0.373224    ...           0.981753
# Tolerance factor(t)        -0.611838    ...           0.094176
# octahedral factor(u)        0.148706    ...          -0.113482
# c/a                        -0.150205    ...          -0.162291
#
#                       X BoilingPoint  X SpecificHeat  X NumberofShells  \
# A AtomicMass               -0.031496        0.089497         -0.031636
# A NumberofNeutrons         -0.039487        0.095895         -0.039536
# A NumberofProtons          -0.021704        0.082216         -0.021990
# A NumberofElectrons        -0.021704        0.082216         -0.021990
# A Period                    0.119832       -0.073153          0.118446
# A Electronegativity        -0.414285        0.525915         -0.412530
# A FirstIonization          -0.503712        0.626417         -0.501260
# A Density                  -0.347696        0.462059         -0.346440
# A MeltingPoint             -0.417173        0.539170         -0.415837
# A BoilingPoint             -0.409100        0.518532         -0.407783
# A SpecificHeat             -0.088749       -0.000290         -0.088495
# A NumberofShells            0.119832       -0.073153          0.118446
# B AtomicMass                0.234830       -0.205773          0.228033
# B NumberofNeutrons          0.272175       -0.266812          0.266113
# B NumberofProtons           0.243418       -0.215580          0.236206
# B NumberofElectrons         0.243418       -0.215580          0.236206
# B Period                    0.253737       -0.239858          0.242921
# B Electronegativity         0.038099        0.012843          0.039003
# B FirstIonization          -0.233042        0.259427         -0.232378
# B Density                   0.111270       -0.089398          0.106018
# B MeltingPoint             -0.297238        0.277229         -0.299129
# B BoilingPoint             -0.218452        0.239048         -0.219773
# B SpecificHeat             -0.247099        0.211058         -0.237823
# B NumberofShells            0.253737       -0.239858          0.242921
# X AtomicMass                0.963963       -0.882282          0.981980
# X NumberofNeutrons          0.954937       -0.869546          0.975275
# X NumberofProtons           0.972041       -0.892991          0.987875
# X NumberofElectrons         0.972041       -0.892991          0.987875
# X Period                    0.996254       -0.937386          1.000000
# X Electronegativity        -0.810745        0.668517         -0.792577
# X FirstIonization          -0.667310        0.490399         -0.650099
# X Density                   0.892823       -0.760140          0.927522
# X MeltingPoint              0.998397       -0.951534          0.998869
# X BoilingPoint              1.000000       -0.955468          0.996254
# X SpecificHeat             -0.955468        1.000000         -0.937386
# X NumberofShells            0.996254       -0.937386          1.000000
# A Ionic radius (pm)         0.526606       -0.616365          0.523571
# B Ionic radius              0.399067       -0.482988          0.375331
# X Ionic radius              0.990914       -0.948717          0.977631
# Tolerance factor(t)         0.080226       -0.116496          0.094413
# octahedral factor(u)       -0.112071        0.002407         -0.124755
# c/a                        -0.168333        0.132992         -0.164225
#
#                       A Ionic radius (pm)  B Ionic radius  X Ionic radius  \
# A AtomicMass                     0.282436        0.076525       -0.012131
# A NumberofNeutrons               0.271329        0.074207       -0.020470
# A NumberofProtons                0.296448        0.078944       -0.001676
# A NumberofElectrons              0.296448        0.078944       -0.001676
# A Period                         0.513672        0.173833        0.134956
# A Electronegativity             -0.659193       -0.309011       -0.378610
# A FirstIonization               -0.839205       -0.389479       -0.464741
# A Density                       -0.447868       -0.156456       -0.311244
# A MeltingPoint                  -0.705508       -0.075974       -0.377747
# A BoilingPoint                  -0.728639       -0.066892       -0.373224
# A SpecificHeat                  -0.368402       -0.086199       -0.112083
# A NumberofShells                 0.513672        0.173833        0.134956
# B AtomicMass                     0.151486        0.646733        0.248517
# B NumberofNeutrons               0.126979        0.517224        0.277522
# B NumberofProtons                0.156029        0.657333        0.257288
# B NumberofElectrons              0.156029        0.657333        0.257288
# B Period                         0.179631        0.708174        0.270251
# B Electronegativity             -0.086086       -0.080442        0.048826
# B FirstIonization               -0.219167       -0.135421       -0.216688
# B Density                        0.043482        0.474290        0.124632
# B MeltingPoint                  -0.111988       -0.339015       -0.287730
# B BoilingPoint                  -0.123487       -0.299227       -0.205526
# B SpecificHeat                  -0.073789       -0.520048       -0.266556
# B NumberofShells                 0.179631        0.708174        0.270251
# X AtomicMass                     0.494758        0.307977        0.923582
# X NumberofNeutrons               0.487281        0.294935        0.911042
# X NumberofProtons                0.501283        0.320553        0.935482
# X NumberofElectrons              0.501283        0.320553        0.935482
# X Period                         0.523571        0.375331        0.977631
# X Electronegativity             -0.168902       -0.229325       -0.860066
# X FirstIonization               -0.014525       -0.128026       -0.728207
# X Density                        0.418872        0.214485        0.839529
# X MeltingPoint                   0.533159        0.388796        0.981753
# X BoilingPoint                   0.526606        0.399067        0.990914
# X SpecificHeat                  -0.616365       -0.482988       -0.948717
# X NumberofShells                 0.523571        0.375331        0.977631
# A Ionic radius (pm)              1.000000        0.352117        0.497787
# B Ionic radius                   0.352117        1.000000        0.413255
# X Ionic radius                   0.497787        0.413255        1.000000
# Tolerance factor(t)              0.669423       -0.436040        0.043298
# octahedral factor(u)             0.101307        0.847658       -0.112573
# c/a                              0.120999       -0.009217       -0.181905
#
#                       Tolerance factor(t)  octahedral factor(u)       c/a
# A AtomicMass                     0.230915              0.074907  0.044053
# A NumberofNeutrons               0.221946              0.077010  0.043109
# A NumberofProtons                0.242807              0.071632  0.044830
# A NumberofElectrons              0.242807              0.071632  0.044830
# A Period                         0.370498              0.100396  0.074441
# A Electronegativity             -0.360813             -0.132964 -0.118709
# A FirstIonization               -0.476797             -0.172303 -0.104329
# A Density                       -0.263312              0.000669 -0.101630
# A MeltingPoint                  -0.577025              0.140091 -0.139961
# A BoilingPoint                  -0.611838              0.148706 -0.150205
# A SpecificHeat                  -0.298858             -0.021756 -0.049549
# A NumberofShells                 0.370498              0.100396  0.074441
# B AtomicMass                    -0.356300              0.573778  0.065103
# B NumberofNeutrons              -0.282710              0.407771  0.094340
# B NumberofProtons               -0.362254              0.581231  0.063205
# B NumberofElectrons             -0.362254              0.581231  0.063205
# B Period                        -0.392315              0.631538  0.041068
# B Electronegativity              0.013783             -0.135593  0.062267
# B FirstIonization               -0.014747             -0.052045 -0.022783
# B Density                       -0.319077              0.431109  0.052092
# B MeltingPoint                   0.151490             -0.255334  0.038490
# B BoilingPoint                   0.099520             -0.248120  0.126866
# B SpecificHeat                   0.376938             -0.439524 -0.039601
# B NumberofShells                -0.392315              0.631538  0.041068
# X AtomicMass                     0.118901             -0.152426 -0.147978
# X NumberofNeutrons               0.122217             -0.157040 -0.144757
# X NumberofProtons                0.115081             -0.148290 -0.151658
# X NumberofElectrons              0.115081             -0.148290 -0.151658
# X Period                         0.094413             -0.124755 -0.164225
# X Electronegativity              0.121631              0.249722  0.222306
# X FirstIonization                0.179460              0.290469  0.221163
# X Density                        0.120794             -0.199146 -0.142363
# X MeltingPoint                   0.094176             -0.113482 -0.162291
# X BoilingPoint                   0.080226             -0.112071 -0.168333
# X SpecificHeat                  -0.116496              0.002407  0.132992
# X NumberofShells                 0.094413             -0.124755 -0.164225
# A Ionic radius (pm)              0.669423              0.101307  0.120999
# B Ionic radius                  -0.436040              0.847658 -0.009217
# X Ionic radius                   0.043298             -0.112573 -0.181905
# Tolerance factor(t)              1.000000             -0.504142  0.141679
# octahedral factor(u)            -0.504142              1.000000  0.095600
# c/a                              0.141679              0.095600  1.000000
#
# [42 rows x 42 columns]

# %%
df=pd.read_csv("Afterfs Train_test.csv")

# %%
print(df)
# Out:
#     A Electronegativity  A FirstIonization  A Density  A BoilingPoint  \
# 0                  2.33             7.4167     11.300            2022
# 1                  2.02             7.2856      9.810            1837
# 23             0.622371              0.728571  1.000000
# 24             0.840671              0.285714  1.000000
# 25             0.868312              0.378571  0.987342
# 26             0.757167              0.614286  1.000000
# 27             0.853466              0.432143  1.000000
# 28             0.596073              0.728571  1.000000
# 29             0.750264              0.521429  0.942643
# ..                  ...                   ...       ...
# 65             1.191753              0.338346  1.000000
# 66             1.034790              0.541353  1.000000
# 67             0.968639              0.646617  1.000000
# 68             0.894811              0.519337  1.455923
# 69             0.825749              0.646409  1.000000
# 70             0.773815              0.756906  1.471850
# 71             0.820244              0.657459  0.517056
# 72             0.902214              0.451531  1.000000
# 73             0.858461              0.525510  0.709596
# 74             0.770810              0.698980  1.467350
# 75             0.861341              0.520408  1.000000
# 76             0.870101              0.505102  1.000000
# 77             0.954200              0.372449  1.000000
# 78             0.761780              0.458647  1.384071
# 79             0.738927              0.503759  1.008958
# 80             0.750179              0.481203  1.000000
# 81             0.637006              0.744361  1.000000
# 82             0.680623              0.475138  0.960474
# 83             0.810586              0.541353  1.000000
# 84             0.843503              0.481203  1.000000
# 85             0.758768              0.646617  1.000000
# 86             0.930223              0.548872  1.458763
# 87             0.948643              0.518797  1.000000
# 88             0.888059              0.403315  1.000000
# 89             0.805597              0.546961  1.000000
# 90             0.820244              0.519337  1.001976
# 91             0.855702              0.408163  1.000000
# 92             0.843814              0.363636  1.000000
# 93             0.830136              0.451531  1.000000
# 94             0.814392              0.479592  0.705416
#
# [95 rows x 11 columns]

# %%
import matplotlib.pyplot as plot
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas import DataFrame

# %%
dataset= r'Afterfs Train_test.csv'
data=pd.DataFrame(pd.read_csv(dataset))
featureData=data.iloc[:,:]
corMat = DataFrame(featureData.corr())  #corr 求相关系数矩阵
print(corMat)
writer = pd.ExcelWriter('3.xlsx')
corMat.to_excel(writer,'Sheet1')
writer.save()
plt.figure(figsize=(20, 30))
sns.heatmap(corMat, annot=False, vmax=1, square=True, cmap="Blues",linewidths=0)
plot.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#                       A Electronegativity  A FirstIonization  A Density  \
# A Electronegativity              1.000000           0.837437   0.769792
# A FirstIonization                0.837437           1.000000   0.583899
# A Density                        0.769792           0.583899   1.000000
# A BoilingPoint                   0.548883           0.589535   0.649901
# B BoilingPoint                   0.059856           0.127374   0.082407
# X Electronegativity              0.034734           0.074096  -0.019563
# A Ionic radius (pm)             -0.659193          -0.839205  -0.447868
# X Ionic radius                  -0.378610          -0.464741  -0.311244
# Tolerance factor(t)             -0.360813          -0.476797  -0.263312
# octahedral factor(u)            -0.132964          -0.172303   0.000669
# c/a                             -0.118709          -0.104329  -0.101630
#
#                       A BoilingPoint  B BoilingPoint  X Electronegativity  \
# A Electronegativity         0.548883        0.059856             0.034734
# A FirstIonization           0.589535        0.127374             0.074096
# A Density                   0.649901        0.082407            -0.019563
# A BoilingPoint              1.000000       -0.027168             0.033533
# B BoilingPoint             -0.027168        1.000000             0.092339
# X Electronegativity         0.033533        0.092339             1.000000
# A Ionic radius (pm)        -0.728639       -0.123487            -0.168902
# X Ionic radius             -0.373224       -0.205526            -0.860066
# Tolerance factor(t)        -0.611838        0.099520             0.121631
# octahedral factor(u)        0.148706       -0.248120             0.249722
# c/a                        -0.150205        0.126866             0.222306
#
#                       A Ionic radius (pm)  X Ionic radius  \
# A Electronegativity             -0.659193       -0.378610
# A FirstIonization               -0.839205       -0.464741
# A Density                       -0.447868       -0.311244
# A BoilingPoint                  -0.728639       -0.373224
# B BoilingPoint                  -0.123487       -0.205526
# X Electronegativity             -0.168902       -0.860066
# A Ionic radius (pm)              1.000000        0.497787
# X Ionic radius                   0.497787        1.000000
# Tolerance factor(t)              0.669423        0.043298
# octahedral factor(u)             0.101307       -0.112573
# c/a                              0.120999       -0.181905
#
#                       Tolerance factor(t)  octahedral factor(u)       c/a
# A Electronegativity             -0.360813             -0.132964 -0.118709
# A FirstIonization               -0.476797             -0.172303 -0.104329
# A Density                       -0.263312              0.000669 -0.101630
# A BoilingPoint                  -0.611838              0.148706 -0.150205
# B BoilingPoint                   0.099520             -0.248120  0.126866
# X Electronegativity              0.121631              0.249722  0.222306
# A Ionic radius (pm)              0.669423              0.101307  0.120999
# X Ionic radius                   0.043298             -0.112573 -0.181905
# Tolerance factor(t)              1.000000             -0.504142  0.141679
# octahedral factor(u)            -0.504142              1.000000  0.095600
# c/a                              0.141679              0.095600  1.000000

# %%
import matplotlib.pyplot as plot
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import svm
import numpy as np
import pandas as pd
from sklearn import preprocessing
from pandas import DataFrame
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from sklearn.model_selection import KFold
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix
from gplearn import genetic
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler, SMOTE
from collections import Counter
from sklearn.model_selection import train_test_split
import sklearn.ensemble as ensemble  # ensemble learning: 集成学习
from sklearn.model_selection import GridSearchCV
import sklearn.metrics as metrics
import matplotlib.pyplot as plt

# %%
dataset= r'Afterfs Train_test.csv' #筛选特征后的训练集

data=pd.DataFrame(pd.read_csv(dataset))

X = data.values[:, :-1]
y = data.values[:, -1]
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=1)


for i in range(X_train.shape[1]):
    X_train[:, [i]] = preprocessing.MinMaxScaler().fit_transform(X_train[:, [i]])



for i in range(X_test.shape[1]):
    X_test[:, [i]] = preprocessing.MinMaxScaler().fit_transform(X_test[:, [i]])

# %%
for a in range(1,10): #循环法调参
 for b in range(1,10):
  clf = RandomForestRegressor(random_state=a,n_estimators=b) #随机森林
  clf.fit(X,y) #拟合
  sse = np.sum((y - clf.predict(X)) ** 2)
  sst = np.sum((y - np.mean(X)) ** 2)
  R2 = 1 - sse / sst #R^2
  o=pearsonr(y,clf.predict(X)) #pearson系数
  if o[0]>0.9 and R2>0.9: #筛选条件
    print(o[0],R2,i,j)
# Out:
# 0.9057390155752023 0.9999999347417909 9 9
# 0.9129381849317406 0.9999999371921002 9 9
# 0.9225829687636835 0.9999999376837769 9 9
# 0.9023348100277921 0.9999999300021999 9 9
# 0.9156569716515093 0.9999999358826867 9 9
# 0.9056607584781368 0.9999999152104634 9 9
# 0.917925726437723 0.9999999318000826 9 9
# 0.905152871097207 0.9999999284017733 9 9
# 0.9106732218867918 0.9999999325391752 9 9
# 0.9074232362442816 0.9999999044029384 9 9
# 0.903104488455653 0.9999998990448077 9 9

# %%
lrTool=RandomForestRegressor(random_state=4,n_estimators=7) #拟合

lrTool.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=7, random_state=4)

# %%
mse = mean_squared_error(y, lrTool.predict(X))
rmse = mse ** (1/2)

sse = np.sum((y - lrTool.predict(X)) ** 2)
sst = np.sum((y - np.mean(X)) ** 2)
R2= 1 - sse / sst

# %%
print(R2) #准确率
print(rmse)
print(pearsonr(y,lrTool.predict(X)))
# Out:
# 0.9999999376837769
# 0.11781837243088258
# (0.9225829687636835, 3.035878897229114e-40)

# %%
# 画图显示
plt.yticks(fontproperties = 'Times New Roman', size = 14)
plt.xticks(fontproperties = 'Times New Roman', size = 14)
plt.rcParams['font.sans-serif'] = 'Roman'
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(y,y,label='Real Data')
plt.scatter(y,lrTool.predict(X),label='Predict',c='r')
ax=plt.gca()
ax.spines['bottom'].set_linewidth(2);###设置底部坐标轴的粗细
ax.spines['left'].set_linewidth(2);####设置左边坐标轴的粗细
ax.spines['right'].set_linewidth(2);###设置右边坐标轴的粗细
ax.spines['top'].set_linewidth(2)
plt.tick_params(width=2)
ax.xaxis.set_tick_params(labelsize=20)
plt.tick_params(which='major',length=8)
plt.tick_params(which='minor',length=4,width=2)
ax.yaxis.set_tick_params(labelsize=20)
xminorLocator = MultipleLocator(1000)
yminorLocator = MultipleLocator(1000)
ax.xaxis.set_minor_locator(xminorLocator)
ax.yaxis.set_minor_locator(yminorLocator)
plt.show()

# %%
from sklearn.model_selection import KFold

# %%
for nk in range(2,20):
 kfolder = KFold(n_splits=nk)
 score=0
 for train, test in kfolder.split(X, y):
   train_data = np.array(data)[train]
   test_data = np.array(data)[test]
   trany=train_data[:,9]
   tranx=train_data[:,:9]
   testx=test_data[:,:9]
   testy=test_data[:,9]
   clf.fit(tranx,trany)
   pu=pearsonr(testy,clf.predict(testx))
   score=score+pu[0]
 print(score/nk)
# Out:
# 0.5222420773019759
# 0.7457258176979341
# 0.6635084869679848
# 0.7726565740377309
# 0.7720481771771884
# 0.7071080720455727
# 0.740092581078881
# 0.554375454305341
# 0.8138236096412583
# 0.7780927137940108
# 0.8093009746790863
# 0.8340292740142802
# 0.7947632573760987
# 0.7625425496407322
# 0.7576042335508462
# 0.7289692159238175
# 0.7202543803996385
# 0.7216560865521391
